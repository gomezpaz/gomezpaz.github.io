# %% [markdown]
# ---
# title: santi
# tags: TeXt
# article_header:
#   type: cover
#   image:
#     src: /screenshot.jpg
# key: 2016-06-01-smaug
# tags: sumo robot programming competition electronics 3dprinting
# ---

# %% [markdown]
# Is this nice?

# %%
# show plot of tesla stock for last week
import matplotlib.pyplot as plt
import pandas as pd
import pandas_datareader.data as web
import datetime

start = datetime.datetime(2020, 8, 1)
end = datetime.datetime(2020, 8, 7)
tesla = web.DataReader('TSLA', 'yahoo', start, end)
tesla.head()
tesla['Close'].plot()
plt.show()

# %% [markdown]
# This is an example of an article writen on jupyter notebooks
